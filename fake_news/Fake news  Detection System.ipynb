# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import re
import string
import seaborn as sns
import matplotlib.pyplot as plt
import streamlit as st

# %%
#Importing the datasets

# %%
df_fake=pd.read_csv('Fake.csv')
df_true=pd.read_csv('True.csv')

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
Inserting a column 'Class as the target feature'

# %%
df_fake['class']=0
df_true['class']=1

# %%
df_true.shape, df_fake.shape
# Out:
# ((21417, 5), (23481, 5))

# %%
df_fake_reduced = df_fake.head(21417)

# %%
df_fake_reduced.shape
# Out:
# (21417, 5)

# %%
#Removing the last 10 rows for manual testing
# Clean and reliable method
df_fake_manual_testing = df_fake_reduced.tail(10)
df_fake_reduced = df_fake_reduced.iloc[:-10]

df_true_manual_testing = df_true.tail(10)
df_true = df_true.iloc[:-10]

# %%
df_fake_reduced.shape, df_true.shape,
# Out:
# ((23461, 5), (21387, 5))

# %%
df_fake_manual_testing['class']=0
df_true_manual_testing['class']=1

# %%
df_fake_manual_testing.head(10)
# Out:
#                                                    title  \
# 23461  REPORT: ‘Federal Government Escalated the Viol...
# 23462  BOILER ROOM – Oregon Standoff, Cuddle Parties,...
# 23463  Eyewitness Says Feds Ambushed Bundys, 100 Shot...
# 23464  Episode #119 – SUNDAY WIRE: ‘You Know the Dril...
# 23465  ‘There’ll be boots on the ground’: US making n...
# 23466  Boston Brakes? How to Hack a New Car With Your...
# 23467  Oregon Governor Says Feds ‘Must Act’ Against P...
# 23468  Ron Paul on Burns Oregon Standoff and Jury Nul...
# 23469     BOILER ROOM: As the Frogs Slowly Boil – EP #40
# 23470  Arizona Rancher Protesting in Oregon is Target...
#
#                                                     text      subject  \
# 23461   KILLED: Rancher and protest spokesman Robert ...  Middle-east
# 23462  Tune in to the Alternate Current Radio Network...  Middle-east
# 23463  Patrick Henningsen 21st Century Wire UPDATE: 1...  Middle-east
# ...

# %%
df_true_manual_testing.head(10)
# Out:
#                                                    title  \
# 21387  Former Libyan prime minister freed after abduc...
# 21388  Britain outlines plans to break free of Europe...
# 21389  Trump must be respected as U.S. president, say...
# 21390  Pakistan rejects role of 'scapegoat for U.S. f...
# 21391  Romanian president opposes plans for judicial ...
# 21392  Iran, Saudi Arabia to exchange diplomatic visi...
# 21393  Danish police identify torso as missing submar...
# 21394  Typhoon batters Hong Kong and south China, thr...
# 21395  Poland to allocate additional $55 bllion on de...
# 21396  Pro-Houthi fighters call powerful Yemen ally '...
#
#                                                     text    subject  \
# 21387  TRIPOLI (Reuters) - Former Libyan Prime Minist...  worldnews
# 21388  LONDON (Reuters) - Britain on Wednesday outlin...  worldnews
# 21389  BERLIN (Reuters) - Chancellor Angela Merkel sa...  worldnews
# ...

# %%
df_manual_testing= pd.concat([df_fake_manual_testing, df_true_manual_testing], axis=0)
df_manual_testing.to_csv('manual_testing.csv')

# %%
Merging True and Fake Dataframes

# %%
df_merge= pd.concat([df_fake_reduced,df_true], axis=0)
df_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
df_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
df= df_merge.drop(['title','subject','date'], axis=1)

# %%
df.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
#Random shuffling th dataframe

# %%
df= df.sample(frac=1)

# %%
df.head()
# Out:
#                                                     text  class
# 4603   Not long before Donald Trump pathetically admi...      0
# 16435  Leave it to the one and only Andrew McCarthy t...      0
# 16547      (Welcome) to America We hope you enjoy our...      0
# 10701  WASHINGTON (Reuters) - Senate Majority Leader ...      1
# 2437   Since Donald Trump began his run for the presi...      0

# %%
df.reset_index(inplace= True)
df.drop(['index'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
df.head()
# Out:
#                                                 text  class
# 0  Not long before Donald Trump pathetically admi...      0
# 1  Leave it to the one and only Andrew McCarthy t...      0
# 2      (Welcome) to America We hope you enjoy our...      0
# 3  WASHINGTON (Reuters) - Senate Majority Leader ...      1
# 4  Since Donald Trump began his run for the presi...      0

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)    
    return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_3209/3432647204.py:3: SyntaxWarning: invalid escape sequence '\['
#   text = re.sub('\[.*?\]', '', text)
# /tmp/ipykernel_3209/3432647204.py:5: SyntaxWarning: invalid escape sequence '\S'
#   text = re.sub('https?://\S+|www\.\S+', '', text)
# /tmp/ipykernel_3209/3432647204.py:9: SyntaxWarning: invalid escape sequence '\w'
#   text = re.sub('\w*\d\w*', '', text)

# %%
df["text"] = df["text"].apply(wordopt)

# %%
Defining the dependent and independet variables

# %%
x= df['text']
y=df['class']

# %%
Spliting into training and test data

# %%
x_train, x_test, y_train,y_test= train_test_split(x,y, test_size= 0.25)

# %%
converting the text to vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
Using logisticregression

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr= LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9868890474491616

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5867
#            1       0.98      0.99      0.99      5345
#
#     accuracy                           0.99     11212
#    macro avg       0.99      0.99      0.99     11212
# weighted avg       0.99      0.99      0.99     11212

# %%
Using a Decsion Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score(xv_test, y_test)
# Out:
# 0.9967891544773457

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5867
#            1       1.00      1.00      1.00      5345
#
#     accuracy                           1.00     11212
#    macro avg       1.00      1.00      1.00     11212
# weighted avg       1.00      1.00      1.00     11212

# %%
Using Gradient Boosting CLassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

GBC = GradientBoostingClassifier(random_state=0)
GBC.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gbc = GBC.predict(xv_test)

# %%
GBC.score(xv_test, y_test)
# Out:
# 0.9955404923296468

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5867
#            1       0.99      1.00      1.00      5345
#
#     accuracy                           1.00     11212
#    macro avg       1.00      1.00      1.00     11212
# weighted avg       1.00      1.00      1.00     11212

# %%
#random forest

# %%
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier(random_state=0)
RFC.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rfc = RFC.predict(xv_test)

# %%
RFC.score(xv_test, y_test)
# Out:
# 0.9869782376025686

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5867
#            1       0.99      0.99      0.99      5345
#
#     accuracy                           0.99     11212
#    macro avg       0.99      0.99      0.99     11212
# weighted avg       0.99      0.99      0.99     11212

# %%
TESTING THE MODEL

# %%
def output_lable(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"
    
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt) 
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_GBC = GBC.predict(new_xv_test)
    pred_RFC = RFC.predict(new_xv_test)

    return print("\n\nLR Prediction: {} \nDT Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(output_lable(pred_LR[0]),                                                                                                       output_lable(pred_DT[0]), 
                                                                                                              output_lable(pred_GBC[0]), 
                                                                                                              output_lable(pred_RFC[0])))

# %%
news = str(input())
manual_testing(news)
# Out:
#  Dua Lipa can do a perfectly controlled headstand. She can also do the flying splits (eka pada koundinyasana II). Hell, she can even do a headstand on a surfboard, a trick she just showed off during her holiday in the Balearic Islands. “I always make time to get a good workout in whenever and wherever I’m in the world,” Lipa tells Vogue. A big part of that routine? Reformer pilates.  For the uninitiated, reformer pilates is a low-impact workout beloved by the likes of Hailey Bieber, Meghan Markle, and yes, Lipa. Today, the singer and Service95 founder shares with Vogue that she’s joining Frame as cofounder and chief creative officer. Dua Lipa on Her Abs and Living Life as Vacation Advertisement  Frame is an at-home version of the reformer machine from your favorite group class, equipped with a screen so you can stream a class anytime you want. Lipa was actually the first person in Europe to have Frame’s reformer in her home. “I love that I can wake up, roll out of bed, and get right 
# ...

# %%
import joblib

# Example: if you trained Logistic Regression and stored it in "lr"
joblib.dump(LR, "fake_news_model.pkl")
joblib.dump(vectorization, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']
